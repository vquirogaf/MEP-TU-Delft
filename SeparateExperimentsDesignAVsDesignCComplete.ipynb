# %% [markdown]
# # This code contains the correct compilation of Design C experiments individually, as the comparison with Design A old, Design A new and Design A*(6arm/4bps - 6bps rec). In addition, it contains intensity measurements without MDA (30 pic) increasing the number to test noise reduction.

# %% [markdown]
# # Read dataframe Separate Experiments

# %%
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import os
import glob
import pandas as pd
import numpy as np
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 22}

plt.rc('font', **font)

from pylab import rcParams
rcParams['figure.figsize'] = 12, 8

float_epsilon = np.finfo(np.float64).eps
LSQ_PARAMS = dict(method='trf', max_nfev=5000, xtol=float_epsilon, ftol=float_epsilon,
                  gtol=float_epsilon, jac='3-point', x_scale='jac', loss='soft_l1', verbose=1, f_scale = 0.5,
                  tr_options=dict(tr_solver='lsmr', regularize=True))
                  
###Read 6bp##########################
name = 'Separate_Experiments_Edits_Intensity_python.csv' #Insert here other data set to compare
path = 'W:\\staff-bulk\\tnw\\BN\LL\\Shared\\Valentina\\Data_Analysis\\SeparateExperimentsBoundFraction\\'
df_int_nsC = pd.read_csv((os.path.join(path, name)))
df = []

# %% [markdown]
# # Add Design A* values here, DesignType An in Excel

# %%
df_int_6nC = df_int_nsC[df_int_nsC['Stickyend'] == 'GTAG']
df_int_6nC = df_int_6nC[df_int_6nC['nanostar_concentration[M]'] == 1.00E-08]
df_int_6bp_6nC = df_int_6nC[df_int_6nC['Number_arms'] == 6]
df_int_6bp_6nC = df_int_6bp_6nC[df_int_6bp_6nC['Sticky_ends'] == 4]

# %%
df_int_6bp_6nC
# Out:
#           date  Inert  Number_arms  Sticky_ends  nanostar_concentration[M]  \
# 1   20221004.0    0.0          6.0          4.0               1.000000e-08
# 2   20221004.0    0.0          6.0          4.0               1.000000e-08
# 3   20221004.0    0.0          6.0          4.0               1.000000e-08
# 4   20221004.0    0.0          6.0          4.0               1.000000e-08
# 5   20221004.0    0.0          6.0          4.0               1.000000e-08
# 6   20221004.0    0.0          6.0          4.0               1.000000e-08
# 7   20221004.0    0.0          6.0          4.0               1.000000e-08
# 8   20221006.0    0.0          6.0          4.0               1.000000e-08
# 9   20221006.0    0.0          6.0          4.0               1.000000e-08
# 10  20221006.0    0.0          6.0          4.0               1.000000e-08
# 11  20221006.0    0.0          6.0          4.0               1.000000e-08
# 12  20221006.0    0.0          6.0          4.0               1.000000e-08
# 13  20221006.0    0.0          6.0          4.0               1.000000e-08
# 14  20221006.0    0.0          6.0          4.0               1.000000e-08
# 15  20221103.0    0.0          6.0          4.0               1.000000e-08
# 16  20221103.0    0.0          6.0          4.0               1.000000e-08
# 17  20221103.0    0.0          6.0          4.0               1.000000e-08
# 18  20221103.0    0.0          6.0          4.0               1.000000e-08
# 19  20221103.0    0.0          6.0          4.0               1.000000e-08
# 20  20221103.0    0.0          6.0          4.0               1.000000e-08
# 21  20221103.0    0.0          6.0          4.0               1.000000e-08
# 22  20221221.0    0.0          6.0          4.0               1.000000e-08
# 23  20221221.0    0.0          6.0          4.0               1.000000e-08
# 24  20221221.0    0.0          6.0          4.0               1.000000e-08
# 25  20221221.0    0.0          6.0          4.0               1.000000e-08
# 26  20221221.0    0.0          6.0          4.0               1.000000e-08
# 27  20221221.0    0.0          6.0          4.0               1.000000e-08
# 28  20221221.0    0.0          6.0          4.0               1.000000e-08
#
#        recept Stickyend DesignType  GibbsFreeEnergy  Mean_Intensity  \
# 1         0.0      GTAG         An             -7.0        552000.0
# 2      1000.0      GTAG         An             -7.0        551000.0
# 3     10000.0      GTAG         An             -7.0        577000.0
# 4     20000.0      GTAG         An             -7.0        601000.0
# 5     50000.0      GTAG         An             -7.0        637000.0
# 6    150000.0      GTAG         An             -7.0        868000.0
# 7    300000.0      GTAG         An             -7.0       1220000.0
# 8         0.0      GTAG         An             -7.0        719000.0
# 9      1000.0      GTAG         An             -7.0        548000.0
# 10    10000.0      GTAG         An             -7.0        617000.0
# 11    20000.0      GTAG         An             -7.0        640000.0
# 12    50000.0      GTAG         An             -7.0        734000.0
# 13   150000.0      GTAG         An             -7.0        948000.0
# 14   300000.0      GTAG         An             -7.0       1260000.0
# 15        0.0      GTAG         An             -7.0        555000.0
# 16     1000.0      GTAG         An             -7.0        551000.0
# 17    10000.0      GTAG         An             -7.0        555000.0
# 18    20000.0      GTAG         An             -7.0        581000.0
# 19    50000.0      GTAG         An             -7.0        664000.0
# 20   150000.0      GTAG         An             -7.0        817000.0
# 21   300000.0      GTAG         An             -7.0       1160000.0
# 22        0.0      GTAG         An             -7.0           424.0
# 23    10000.0      GTAG         An             -7.0           432.0
# 24   300000.0      GTAG         An             -7.0           975.0
# 25   600000.0      GTAG         An             -7.0          1010.0
# 26   750000.0      GTAG         An             -7.0          1160.0
# 27  1140000.0      GTAG         An             -7.0          1050.0
# 28  3750000.0      GTAG         An             -7.0           983.0
#
#         I_max      I_br  Mean_Intensity_norm_max
# 1   1220000.0  551000.0                  0.00149
# 2   1220000.0  551000.0                  0.00000
# 3   1220000.0  551000.0                  0.03890
# 4   1220000.0  551000.0                  0.07480
# 5   1220000.0  551000.0                  0.12900
# 6   1220000.0  551000.0                  0.47400
# 7   1220000.0  551000.0                  1.00000
# 8   1260000.0  548000.0                  0.24000
# 9   1260000.0  548000.0                  0.00000
# 10  1260000.0  548000.0                  0.09690
# 11  1260000.0  548000.0                  0.12900
# 12  1260000.0  548000.0                  0.26100
# 13  1260000.0  548000.0                  0.56200
# 14  1260000.0  548000.0                  1.00000
# 15  1160000.0  551000.0                  1.07000
# 16  1160000.0  551000.0                  0.00000
# 17  1160000.0  551000.0                  0.00657
# 18  1160000.0  551000.0                  0.04930
# 19  1160000.0  551000.0                  0.18600
# 20  1160000.0  551000.0                  0.43700
# 21  1160000.0  551000.0                  1.00000
# 22     1160.0     424.0                  0.00000
# 23     1160.0     424.0                  0.01090
# 24     1160.0     424.0                  0.74900
# 25     1160.0     424.0                  0.79600
# 26     1160.0     424.0                  1.00000
# 27     1160.0     424.0                  0.85100
# 28     1160.0     424.0                  0.76000

# %% [markdown]
# # Add Design C values here

# %%
df_int_6_DC = df_int_nsC[df_int_nsC['Stickyend'] == 'GTAGAA']
df_int_6_DC = df_int_6_DC[df_int_6_DC['DesignType'] == "C"]
df_int_6_DC = df_int_6_DC[df_int_6_DC['nanostar_concentration[M]'] == 1.00E-08]
df_int_6bp_6n_DC = df_int_6_DC[df_int_6_DC['Number_arms'] == 6]
df_int_6bp_6n_DC = df_int_6bp_6n_DC[df_int_6bp_6n_DC['Sticky_ends'] == 6]

# %%
df_int_6bp_6n_DC
# Out:
#           date  Inert  Number_arms  Sticky_ends  nanostar_concentration[M]  \
# 50  20231122.0    0.0          6.0          6.0               1.000000e-08
# 51  20231122.0    0.0          6.0          6.0               1.000000e-08
# 52  20231122.0    0.0          6.0          6.0               1.000000e-08
# 53  20231122.0    0.0          6.0          6.0               1.000000e-08
# 54  20231122.0    0.0          6.0          6.0               1.000000e-08
# 55  20231122.0    0.0          6.0          6.0               1.000000e-08
# 56  20231122.0    0.0          6.0          6.0               1.000000e-08
# 71  20231206.0    0.0          6.0          6.0               1.000000e-08
# 72  20231206.0    0.0          6.0          6.0               1.000000e-08
# 73  20231206.0    0.0          6.0          6.0               1.000000e-08
# 74  20231206.0    0.0          6.0          6.0               1.000000e-08
# 75  20231206.0    0.0          6.0          6.0               1.000000e-08
# 76  20231206.0    0.0          6.0          6.0               1.000000e-08
# 77  20231206.0    0.0          6.0          6.0               1.000000e-08
#
#       recept Stickyend DesignType  GibbsFreeEnergy  Mean_Intensity   I_max  \
# 50       0.0    GTAGAA          C             -7.0          2460.0  3700.0
# 51    3000.0    GTAGAA          C             -7.0          3700.0  3700.0
# 52   10000.0    GTAGAA          C             -7.0          1300.0  3700.0
# 53   20000.0    GTAGAA          C             -7.0          1250.0  3700.0
# 54   50000.0    GTAGAA          C             -7.0          1370.0  3700.0
# 55  150000.0    GTAGAA          C             -7.0          1120.0  3700.0
# 56  300000.0    GTAGAA          C             -7.0          1390.0  3700.0
# 71       0.0    GTAGAA          C             -7.0          2360.0  2710.0
# 72    3000.0    GTAGAA          C             -7.0          2260.0  2710.0
# 73   10000.0    GTAGAA          C             -7.0          2410.0  2710.0
# 74   20000.0    GTAGAA          C             -7.0          2320.0  2710.0
# 75   50000.0    GTAGAA          C             -7.0          2710.0  2710.0
# 76  150000.0    GTAGAA          C             -7.0          1760.0  2710.0
# 77  300000.0    GTAGAA          C             -7.0          1750.0  2710.0
#
#       I_br  Mean_Intensity_norm_max
# 50  1120.0                   0.5190
# 51  1120.0                   1.0000
# 52  1120.0                   0.0719
# 53  1120.0                   0.0509
# 54  1120.0                   0.0991
# 55  1120.0                   0.0000
# 56  1120.0                   0.1040
# 71  1750.0                   0.6310
# 72  1750.0                   0.5320
# 73  1750.0                   0.6840
# 74  1750.0                   0.5960
# 75  1750.0                   1.0000
# 76  1750.0                   0.0188
# 77  1750.0                   0.0000

# %% [markdown]
# # Add Design C no MDA here

# %%
df_int_6_DC_NO = df_int_nsC[df_int_nsC['Stickyend'] == 'GTAGAA']
df_int_6_DC_NO = df_int_6_DC_NO[df_int_6_DC_NO['DesignType'] == "C-noMDA"]
df_int_6_DC_NO = df_int_6_DC_NO[df_int_6_DC_NO['nanostar_concentration[M]'] == 1.00E-08]
df_int_6bp_6n_DC_NO = df_int_6_DC_NO[df_int_6_DC_NO['Number_arms'] == 6]
df_int_6bp_6n_DC_NO = df_int_6bp_6n_DC_NO[df_int_6bp_6n_DC_NO['Sticky_ends'] == 6]

# %%
df_int_6_DC_NO
# Out:
#           date  Inert  Number_arms  Sticky_ends  nanostar_concentration[M]  \
# 57  20231123.0    0.0          6.0          6.0               1.000000e-08
# 58  20231123.0    0.0          6.0          6.0               1.000000e-08
# 59  20231123.0    0.0          6.0          6.0               1.000000e-08
# 60  20231123.0    0.0          6.0          6.0               1.000000e-08
# 61  20231123.0    0.0          6.0          6.0               1.000000e-08
# 62  20231123.0    0.0          6.0          6.0               1.000000e-08
# 63  20231123.0    0.0          6.0          6.0               1.000000e-08
#
#       recept Stickyend DesignType  GibbsFreeEnergy  Mean_Intensity   I_max  \
# 57       0.0    GTAGAA    C-noMDA             -7.0          2650.0  3150.0
# 58    3000.0    GTAGAA    C-noMDA             -7.0          3150.0  3150.0
# 59   10000.0    GTAGAA    C-noMDA             -7.0          2260.0  3150.0
# 60   20000.0    GTAGAA    C-noMDA             -7.0          1360.0  3150.0
# 61   50000.0    GTAGAA    C-noMDA             -7.0          1430.0  3150.0
# 62  150000.0    GTAGAA    C-noMDA             -7.0          1200.0  3150.0
# 63  300000.0    GTAGAA    C-noMDA             -7.0          1420.0  3150.0
#
#       I_br  Mean_Intensity_norm_max
# 57  1200.0                   0.7410
# 58  1200.0                   1.0000
# 59  1200.0                   0.5400
# 60  1200.0                   0.0824
# 61  1200.0                   0.1160
# 62  1200.0                   0.0000
# 63  1200.0                   0.1120

# %% [markdown]
# # Add Desing C MDA + 2hr here

# %%
df_int_6_DC_2h = df_int_nsC[df_int_nsC['Stickyend'] == 'GTAGAA']
df_int_6_DC_2h = df_int_6_DC_2h[df_int_6_DC_2h['DesignType'] == "C+2h"]
df_int_6_DC_2h = df_int_6_DC_2h[df_int_6_DC_2h['nanostar_concentration[M]'] == 1.00E-08]
df_int_6bp_6n_DC_2h = df_int_6_DC_2h[df_int_6_DC_2h['Number_arms'] == 6]
df_int_6bp_6n_DC_2h = df_int_6bp_6n_DC_2h[df_int_6bp_6n_DC_2h['Sticky_ends'] == 6]

# %%
df_int_6bp_6n_DC_2h
# Out:
#           date  Inert  Number_arms  Sticky_ends  nanostar_concentration[M]  \
# 64  20231124.0    0.0          6.0          6.0               1.000000e-08
# 65  20231124.0    0.0          6.0          6.0               1.000000e-08
# 66  20231124.0    0.0          6.0          6.0               1.000000e-08
# 67  20231124.0    0.0          6.0          6.0               1.000000e-08
# 68  20231124.0    0.0          6.0          6.0               1.000000e-08
# 69  20231124.0    0.0          6.0          6.0               1.000000e-08
# 70  20231124.0    0.0          6.0          6.0               1.000000e-08
#
#       recept Stickyend DesignType  GibbsFreeEnergy  Mean_Intensity   I_max  \
# 64       0.0    GTAGAA       C+2h             -7.0          3710.0  4710.0
# 65    3000.0    GTAGAA       C+2h             -7.0          3740.0  4710.0
# 66   10000.0    GTAGAA       C+2h             -7.0          3870.0  4710.0
# 67   20000.0    GTAGAA       C+2h             -7.0          3720.0  4710.0
# 68   50000.0    GTAGAA       C+2h             -7.0          4710.0  4710.0
# 69  150000.0    GTAGAA       C+2h             -7.0          4670.0  4710.0
# 70  300000.0    GTAGAA       C+2h             -7.0          4660.0  4710.0
#
#       I_br  Mean_Intensity_norm_max
# 64  3710.0                   0.0000
# 65  3710.0                   0.0362
# 66  3710.0                   0.1620
# 67  3710.0                   0.0116
# 68  3710.0                   1.0000
# 69  3710.0                   0.9650
# 70  3710.0                   0.9460

# %% [markdown]
# # Add Desing C MDA + 1.5hr here

# %%
df_int_6_DC_1h = df_int_nsC[df_int_nsC['Stickyend'] == 'GTAGAA']
df_int_6_DC_1h = df_int_6_DC_1h[df_int_6_DC_1h['DesignType'] == "C+1.5h"]
df_int_6_DC_1h = df_int_6_DC_1h[df_int_6_DC_1h['nanostar_concentration[M]'] == 1.00E-08]
df_int_6bp_6n_DC_1h = df_int_6_DC_1h[df_int_6_DC_1h['Number_arms'] == 6]
df_int_6bp_6n_DC_1h = df_int_6bp_6n_DC_1h[df_int_6bp_6n_DC_1h['Sticky_ends'] == 6]

# %%
df_int_6bp_6n_DC_1h
# Out:
#           date  Inert  Number_arms  Sticky_ends  nanostar_concentration[M]  \
# 78  20231207.0    0.0          6.0          6.0               1.000000e-08
# 79  20231207.0    0.0          6.0          6.0               1.000000e-08
# 80  20231207.0    0.0          6.0          6.0               1.000000e-08
# 81  20231207.0    0.0          6.0          6.0               1.000000e-08
# 82  20231207.0    0.0          6.0          6.0               1.000000e-08
# 83  20231207.0    0.0          6.0          6.0               1.000000e-08
# 84  20231207.0    0.0          6.0          6.0               1.000000e-08
#
#       recept Stickyend DesignType  GibbsFreeEnergy  Mean_Intensity   I_max  \
# 78       0.0    GTAGAA     C+1.5h             -7.0          2410.0  2730.0
# 79    3000.0    GTAGAA     C+1.5h             -7.0          2440.0  2730.0
# 80   10000.0    GTAGAA     C+1.5h             -7.0          2400.0  2730.0
# 81   20000.0    GTAGAA     C+1.5h             -7.0          2530.0  2730.0
# 82   50000.0    GTAGAA     C+1.5h             -7.0          2730.0  2730.0
# 83  150000.0    GTAGAA     C+1.5h             -7.0          1870.0  2730.0
# 84  300000.0    GTAGAA     C+1.5h             -7.0          1770.0  2730.0
#
#       I_br  Mean_Intensity_norm_max
# 78  1770.0                    0.669
# 79  1770.0                    0.696
# 80  1770.0                    0.653
# 81  1770.0                    0.792
# 82  1770.0                    1.000
# 83  1770.0                    0.106
# 84  1770.0                    0.000

# %% [markdown]
# # Add  Design A values here

# %%
df_int_6_DA = df_int_nsC[df_int_nsC['Stickyend'] == 'GTAGAA']
df_int_6_DA = df_int_6_DA[df_int_6_DA['DesignType'] == "A"]
df_int_6_DA = df_int_6_DA[df_int_6_DA['nanostar_concentration[M]'] == 1.00E-08]
df_int_6bp_6n_DA = df_int_6_DA[df_int_6_DA['Number_arms'] == 6]
df_int_6bp_6n_DA = df_int_6bp_6n_DA[df_int_6bp_6n_DA['Sticky_ends'] == 6]

# %%
df_int_6_DA
# Out:
#           date  Inert  Number_arms  Sticky_ends  nanostar_concentration[M]  \
# 29  20231101.0    0.0          6.0          6.0               1.000000e-08
# 30  20231101.0    0.0          6.0          6.0               1.000000e-08
# 31  20231101.0    0.0          6.0          6.0               1.000000e-08
# 32  20231101.0    0.0          6.0          6.0               1.000000e-08
# 33  20231101.0    0.0          6.0          6.0               1.000000e-08
# 34  20231101.0    0.0          6.0          6.0               1.000000e-08
# 35  20231101.0    0.0          6.0          6.0               1.000000e-08
# 36  20231110.0    0.0          6.0          6.0               1.000000e-08
# 37  20231110.0    0.0          6.0          6.0               1.000000e-08
# 38  20231110.0    0.0          6.0          6.0               1.000000e-08
# 39  20231110.0    0.0          6.0          6.0               1.000000e-08
# 40  20231110.0    0.0          6.0          6.0               1.000000e-08
# 41  20231110.0    0.0          6.0          6.0               1.000000e-08
# 42  20231110.0    0.0          6.0          6.0               1.000000e-08
#
#       recept Stickyend DesignType  GibbsFreeEnergy  Mean_Intensity   I_max  \
# 29       0.0    GTAGAA          A             -7.0           685.0   862.0
# 30    1000.0    GTAGAA          A             -7.0           736.0   862.0
# 31   10000.0    GTAGAA          A             -7.0           742.0   862.0
# 32   20000.0    GTAGAA          A             -7.0           766.0   862.0
# 33   50000.0    GTAGAA          A             -7.0           798.0   862.0
# 34  150000.0    GTAGAA          A             -7.0           862.0   862.0
# 35  300000.0    GTAGAA          A             -7.0           832.0   862.0
# 36       0.0    GTAGAA          A             -7.0          1720.0  4310.0
# 37    1000.0    GTAGAA          A             -7.0          1830.0  4310.0
# 38   10000.0    GTAGAA          A             -7.0          2070.0  4310.0
# 39   20000.0    GTAGAA          A             -7.0          2340.0  4310.0
# 40   50000.0    GTAGAA          A             -7.0          4310.0  4310.0
# 41  150000.0    GTAGAA          A             -7.0          2780.0  4310.0
# 42  300000.0    GTAGAA          A             -7.0          2290.0  4310.0
#
#       I_br  Mean_Intensity_norm_max
# 29   685.0                   0.0000
# 30   685.0                   0.2880
# 31   685.0                   0.3220
# 32   685.0                   0.4580
# 33   685.0                   0.6380
# 34   685.0                   1.0000
# 35   685.0                   0.8310
# 36  1720.0                   0.0000
# 37  1720.0                   0.0427
# 38  1720.0                   0.1370
# 39  1720.0                   0.2400
# 40  1720.0                   1.0000
# 41  1720.0                   0.4100
# 42  1720.0                   0.2210

# %% [markdown]
# # Add  Design A no MDA values here

# %%
df_int_6_DA_NO = df_int_nsC[df_int_nsC['Stickyend'] == 'GTAGAA']
df_int_6_DA_NO = df_int_6_DA_NO[df_int_6_DA_NO['DesignType'] == "A-noMDA"]
df_int_6_DA_NO = df_int_6_DA_NO[df_int_6_DA_NO['nanostar_concentration[M]'] == 1.00E-08]
df_int_6bp_6n_DA_NO = df_int_6_DA_NO[df_int_6_DA_NO['Number_arms'] == 6]
df_int_6bp_6n_DA_NO = df_int_6bp_6n_DA_NO[df_int_6bp_6n_DA_NO['Sticky_ends'] == 6]

# %%
df_int_6_DA_NO
# Out:
#           date  Inert  Number_arms  Sticky_ends  nanostar_concentration[M]  \
# 43  20231111.0    0.0          6.0          6.0               1.000000e-08
# 44  20231111.0    0.0          6.0          6.0               1.000000e-08
# 45  20231111.0    0.0          6.0          6.0               1.000000e-08
# 46  20231111.0    0.0          6.0          6.0               1.000000e-08
# 47  20231111.0    0.0          6.0          6.0               1.000000e-08
# 48  20231111.0    0.0          6.0          6.0               1.000000e-08
# 49  20231111.0    0.0          6.0          6.0               1.000000e-08
#
#       recept Stickyend DesignType  GibbsFreeEnergy  Mean_Intensity   I_max  \
# 43       0.0    GTAGAA    A-noMDA             -7.0          2070.0  2940.0
# 44    1000.0    GTAGAA    A-noMDA             -7.0          2580.0  2940.0
# 45   10000.0    GTAGAA    A-noMDA             -7.0          2210.0  2940.0
# 46   20000.0    GTAGAA    A-noMDA             -7.0          2820.0  2940.0
# 47   50000.0    GTAGAA    A-noMDA             -7.0          2940.0  2940.0
# 48  150000.0    GTAGAA    A-noMDA             -7.0          2910.0  2940.0
# 49  300000.0    GTAGAA    A-noMDA             -7.0          2350.0  2940.0
#
#       I_br  Mean_Intensity_norm_max
# 43  2070.0                    0.000
# 44  2070.0                    0.583
# 45  2070.0                    0.163
# 46  2070.0                    0.859
# 47  2070.0                    1.000
# 48  2070.0                    0.962
# 49  2070.0                    0.322

# %% [markdown]
# # Average all dataframes, new condition DesignType added to create error bar within same kind of data

# %%
#Data set 
#Data A*
df_6_6nC = df_int_6bp_6nC.groupby(['recept', 'DesignType'], as_index = True).agg({'Mean_Intensity_norm_max': ['mean', 'std']}).reset_index()
df_6_6nC.columns = ['_'.join(col).strip() for col in df_6_6nC.columns.values]

#Data A
df_int_6_DA = df_int_6bp_6n_DA.groupby(['recept', 'DesignType'], as_index = True).agg({'Mean_Intensity_norm_max': ['mean', 'std']}).reset_index()
df_int_6_DA.columns = ['_'.join(col).strip() for col in df_int_6_DA.columns.values]

#Data C
df_int_6_DC = df_int_6bp_6n_DC.groupby(['recept', 'DesignType'], as_index = True).agg({'Mean_Intensity_norm_max': ['mean', 'std']}).reset_index()
df_int_6_DC.columns = ['_'.join(col).strip() for col in df_int_6_DC.columns.values]

#Data C- no MDA 
df_int_6_DC_NO = df_int_6bp_6n_DC_NO.groupby(['recept', 'DesignType'], as_index = True).agg({'Mean_Intensity_norm_max': ['mean', 'std']}).reset_index()
df_int_6_DC_NO.columns = ['_'.join(col).strip() for col in df_int_6_DC_NO.columns.values]

#Data C+2h 
df_int_6_DC_2h = df_int_6bp_6n_DC_2h.groupby(['recept', 'DesignType'], as_index = True).agg({'Mean_Intensity_norm_max': ['mean', 'std']}).reset_index()
df_int_6_DC_2h.columns = ['_'.join(col).strip() for col in df_int_6_DC_2h.columns.values]

#Data C+1.5h
df_int_6_DC_1h = df_int_6bp_6n_DC_1h.groupby(['recept', 'DesignType'], as_index = True).agg({'Mean_Intensity_norm_max': ['mean', 'std']}).reset_index()
df_int_6_DC_1h.columns = ['_'.join(col).strip() for col in df_int_6_DC_1h.columns.values]

#Data A- no MDA 
df_int_6_DA_NO = df_int_6bp_6n_DA_NO.groupby(['recept', 'DesignType'], as_index = True).agg({'Mean_Intensity_norm_max': ['mean', 'std']}).reset_index()
df_int_6_DA_NO.columns = ['_'.join(col).strip() for col in df_int_6_DA_NO.columns.values]

# %% [markdown]
# # Average bound fraction Design A*

# %%
fig = plt.figure(figsize=(8, 8))

plt.errorbar(df_6_6nC.recept_,df_6_6nC.Mean_Intensity_norm_max_mean, yerr=df_6_6nC.Mean_Intensity_norm_max_std/np.sqrt(len(df_int_6bp_6nC.date)/7), fmt='o-', markersize = 7, capthick=4,elinewidth = 2, capsize = 4, color='#5f02d9',label = 'GTAG, 4n')
plt.xscale('log')
plt.yscale('log')

plt.title("Bound fraction vs Receptor Density Design A*")
plt.ylim(1E-2,1.15)
#plt.xlim(900,650000)
plt.xlabel('Receptor density / $\\mu m^{-2}$')
plt.ylabel('Bound fraction $\\Theta$')
plt.grid()
plt.legend()
#name = '6bp_6n_mean_adsorption.png'
#plt.savefig((os.path.join(path, name)), format='png') #this in case I want to export the image as png
plt.show()
# Out:
# C:\Users\vquir\anaconda3\lib\site-packages\numpy\core\_methods.py:44: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims, initial, where)
# C:\Users\vquir\anaconda3\lib\site-packages\numpy\core\_methods.py:40: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial, where)
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# # Average Bound Fraction Desing C MDA, MDA+2h, no MDA, MDA+1.5h missing

# %%
fig = plt.figure(figsize=(10, 10))

plt.errorbar(df_int_6_DC.recept_,df_int_6_DC.Mean_Intensity_norm_max_mean, yerr=df_int_6_DC.Mean_Intensity_norm_max_std/np.sqrt(len(df_int_6bp_6n_DC.date)/7), fmt='o-', markersize = 7, capthick=4,elinewidth = 2, capsize = 4, color='#d9027c')
#plt.errorbar(df_int_6_DC_2h.recept_,df_int_6_DC_2h.Mean_Intensity_norm_max_mean, yerr=df_int_6_DC_2h.Mean_Intensity_norm_max_std/np.sqrt(len(df_int_6bp_6n_DC_2h.date)/7), fmt='o-', markersize = 7, capthick=4,elinewidth = 2, capsize = 4, color='#7cd902',label = 'MDA+2h')
#plt.errorbar(df_int_6_DC_1h.recept_,df_int_6_DC_1h.Mean_Intensity_norm_max_mean, yerr=df_int_6_DC_1h.Mean_Intensity_norm_max_std/np.sqrt(len(df_int_6bp_6n_DC_1h.date)/7), fmt='o-', markersize = 7, capthick=4,elinewidth = 2, capsize = 4, color='#02d9cb',label = 'MDA+1.5h')
#plt.errorbar(df_int_6_DC_NO.recept_,df_int_6_DC_NO.Mean_Intensity_norm_max_mean, yerr=df_int_6_DC_NO.Mean_Intensity_norm_max_std/np.sqrt(len(df_int_6bp_6n_DC_NO.date)/7), fmt='o-', markersize = 7, capthick=4,elinewidth = 2, capsize = 4, color='#0210d9',label = 'no MDA')


plt.xscale('log')
plt.yscale('log')

#plt.title("Bound fraction vs Receptor Density Design C ")
plt.ylim(1E-2,2)
#plt.xlim(-1,1E6)
plt.xlabel('Receptor density / $\\mu m^{-2}$')
plt.ylabel('Bound fraction $\\Theta$')
plt.grid()
plt.legend()
#name = '6bp_6n_mean_adsorption.png'
#plt.savefig((os.path.join(path, name)), format='png') #this in case I want to export the image as png
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fig = plt.figure(figsize=(10, 10))

plt.errorbar(df_int_6_DC.recept_,df_int_6_DC.Mean_Intensity_norm_max_mean, yerr=df_int_6_DC.Mean_Intensity_norm_max_std/np.sqrt(len(df_int_6bp_6n_DC.date)/7), fmt='o-', markersize = 7, capthick=4,elinewidth = 2, capsize = 4, color='#d9027c',label = 'MDA')
#plt.errorbar(df_int_6_DC_2h.recept_,df_int_6_DC_2h.Mean_Intensity_norm_max_mean, yerr=df_int_6_DC_2h.Mean_Intensity_norm_max_std/np.sqrt(len(df_int_6bp_6n_DC_2h.date)/7), fmt='o-', markersize = 7, capthick=4,elinewidth = 2, capsize = 4, color='#7cd902',label = 'MDA+2h')
#plt.errorbar(df_int_6_DC_1h.recept_,df_int_6_DC_1h.Mean_Intensity_norm_max_mean, yerr=df_int_6_DC_1h.Mean_Intensity_norm_max_std/np.sqrt(len(df_int_6bp_6n_DC_1h.date)/7), fmt='o-', markersize = 7, capthick=4,elinewidth = 2, capsize = 4, color='#02d9cb',label = 'MDA+1.5h')
#plt.errorbar(df_int_6_DC_NO.recept_,df_int_6_DC_NO.Mean_Intensity_norm_max_mean, yerr=df_int_6_DC_NO.Mean_Intensity_norm_max_std/np.sqrt(len(df_int_6bp_6n_DC_NO.date)/7), fmt='o-', markersize = 7, capthick=4,elinewidth = 2, capsize = 4, color='#0210d9',label = 'no MDA')


plt.xscale('log')
plt.yscale('log')

plt.title("Bound fraction vs Receptor Density Design C ")
plt.ylim(1E-2,2)
#plt.xlim(-1,1E6)
plt.xlabel('Receptor density / $\\mu m^{-2}$')
plt.ylabel('Bound fraction $\\Theta$')
plt.grid()
plt.legend()
#name = '6bp_6n_mean_adsorption.png'
#plt.savefig((os.path.join(path, name)), format='png') #this in case I want to export the image as png
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 fig = plt.figure(figsize=(10, 10))
#       3 plt.errorbar(df_int_6_DC.recept_,df_int_6_DC.Mean_Intensity_norm_max_mean, yerr=df_int_6_DC.Mean_Intensity_norm_max_std/np.sqrt(len(df_int_6bp_6n_DC.date)/7), fmt='o-', markersize = 7, capthick=4,elinewidth = 2, capsize = 4, color='#d9027c',label = 'MDA')
#       4 #plt.errorbar(df_int_6_DC_2h.recept_,df_int_6_DC_2h.Mean_Intensity_norm_max_mean, yerr=df_int_6_DC_2h.Mean_Intensity_norm_max_std/np.sqrt(len(df_int_6bp_6n_DC_2h.date)/7), fmt='o-', markersize = 7, capthick=4,elinewidth = 2, capsize = 4, color='#7cd902',label = 'MDA+2h')
#       5 #plt.errorbar(df_int_6_DC_1h.recept_,df_int_6_DC_1h.Mean_Intensity_norm_max_mean, yerr=df_int_6_DC_1h.Mean_Intensity_norm_max_std/np.sqrt(len(df_int_6bp_6n_DC_1h.date)/7), fmt='o-', markersize = 7, capthick=4,elinewidth = 2, capsize = 4, color='#02d9cb',label = 'MDA+1.5h')
#       6 #plt.errorbar(df_int_6_DC_NO.recept_,df_int_6_DC_NO.Mean_Intensity_norm_max_mean, yerr=df_int_6_DC_NO.Mean_Intensity_norm_max_std/np.sqrt(len(df_int_6bp_6n_DC_NO.date)/7), fmt='o-', markersize = 7, capthick=4,elinewidth = 2, capsize = 4, color='#0210d9',label = 'no MDA')
#
# NameError: name 'plt' is not defined

# %% [markdown]
# # To check if there is a problem with Data from MDA + 2h, I reflected the values in the x axis

# %%
# Reflect the y-coordinates
x_reflected = -df_int_6_DC_2h.recept_

fig = plt.figure(figsize=(12, 12))
# Plot the reflected data
plt.errorbar(df_int_6_DC.recept_,df_int_6_DC.Mean_Intensity_norm_max_mean, yerr=df_int_6_DC.Mean_Intensity_norm_max_std/np.sqrt(len(df_int_6bp_6n_DC.date)/7), fmt='o-', markersize = 7, capthick=4,elinewidth = 2, capsize = 4, color='#d9027c',label = 'MDA')
plt.errorbar(df_int_6_DC_2h.recept_,df_int_6_DC_2h.Mean_Intensity_norm_max_mean, yerr=df_int_6_DC_2h.Mean_Intensity_norm_max_std/np.sqrt(len(df_int_6bp_6n_DC_2h.date)/7), fmt='o-', markersize = 7, capthick=4,elinewidth = 2, capsize = 4, color='#7cd902',label = 'MDA+2h')
plt.errorbar(df_int_6_DC_1h.recept_,df_int_6_DC_1h.Mean_Intensity_norm_max_mean, yerr=df_int_6_DC_1h.Mean_Intensity_norm_max_std/np.sqrt(len(df_int_6bp_6n_DC_1h.date)/7), fmt='o-', markersize = 7, capthick=4,elinewidth = 2, capsize = 4, color='#02d9cb',label = 'MDA+1.5h')
plt.errorbar(x_reflected, df_int_6_DC_2h.Mean_Intensity_norm_max_mean, yerr=df_int_6_DC_2h.Mean_Intensity_norm_max_std/np.sqrt(len(df_int_6bp_6n_DC_2h.date)/7), fmt='o-', markersize=7, capthick=4, elinewidth=2, capsize=4, color='black', label='Reflected MDA+2h')
#plt.errorbar(df_int_6_DC_2h.recept_,df_int_6_DC_2h.Mean_Intensity_norm_max_mean, yerr=df_int_6_DC_2h.Mean_Intensity_norm_max_std/np.sqrt(len(df_int_6bp_6n_DC_2h.date)/7), fmt='o-', markersize = 7, capthick=4,elinewidth = 2, capsize = 4, color='#0210d9',label = 'MDA+2h')
#plt.errorbar(df_int_6_DC.recept_,df_int_6_DC.Mean_Intensity_norm_max_mean, yerr=df_int_6_DC.Mean_Intensity_norm_max_std/np.sqrt(len(df_int_6bp_6n_DC.date)/7), fmt='o-', markersize = 7, capthick=4,elinewidth = 2, capsize = 4, color='#d9027c',label = 'MDA')

# Set the y-axis limits to include both the original and reflected data
plt.xlim(min(x_reflected)-0.1, max(df_int_6_DC_2h.recept_)+1)
#plt.xlim(-150000, 150000)


# Add labels and legend


#plt.xscale('log')
#plt.yscale('log')


plt.title("Bound fraction vs Receptor Density Design C (MDA+2h Reflected)")
plt.xlabel('Receptor density / $\\mu m^{-2}$')
plt.ylabel('Reflected Bound fraction $\\Theta$')
plt.grid()
plt.legend()
# Out:
# C:\Users\vquir\anaconda3\lib\site-packages\numpy\core\_methods.py:44: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims, initial, where)
# C:\Users\vquir\anaconda3\lib\site-packages\numpy\core\_methods.py:40: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial, where)
# C:\Users\vquir\anaconda3\lib\site-packages\numpy\core\_methods.py:44: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims, initial, where)
# C:\Users\vquir\anaconda3\lib\site-packages\numpy\core\_methods.py:40: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial, where)
# C:\Users\vquir\anaconda3\lib\site-packages\numpy\core\_methods.py:44: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims, initial, where)
# C:\Users\vquir\anaconda3\lib\site-packages\numpy\core\_methods.py:40: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial, where)

# %% [markdown]
# # Average Bound Fraction Design A MDA, no MDA

# %%
df_int_6_DA_NO = df_int_nsC[df_int_nsC['Stickyend'] == 'GTAGAA']
df_int_6_DA_NO = df_int_6_DA_NO[df_int_6_DA_NO['DesignType'] == "A-noMDA"]
df_int_6_DA_NO = df_int_6_DA_NO[df_int_6_DA_NO['nanostar_concentration[M]'] == 1.00E-08]
df_int_6bp_6n_DA_NO = df_int_6_DA_NO[df_int_6_DA_NO['Number_arms'] == 6]
df_int_6bp_6n_DA_NO = df_int_6bp_6n_DA_NO[df_int_6bp_6n_DA_NO['Sticky_ends'] == 6]

# %%
df_int_6_DA_NO.recept_
# Out:
# 0         0.0
# 1      1000.0
# 2     10000.0
# 3     20000.0
# 4     50000.0
# 5    150000.0
# 6    300000.0
# Name: recept_, dtype: float64

# %%
fig = plt.figure(figsize=(10, 10))

plt.errorbar(df_int_6_DA.recept_,df_int_6_DA.Mean_Intensity_norm_max_mean, yerr=df_int_6_DA.Mean_Intensity_norm_max_std/np.sqrt(len(df_int_6bp_6n_DA.date)/7), fmt='o-', markersize = 7, capthick=4,elinewidth = 2, capsize = 4, color='#027cd9',label = 'MDA')
plt.errorbar(df_int_6_DA_NO.recept_,df_int_6_DA_NO.Mean_Intensity_norm_max_mean, yerr=df_int_6_DA_NO.Mean_Intensity_norm_max_std/np.sqrt(len(df_int_6bp_6n_DA_NO.date)/7), fmt='o-', markersize = 7, capthick=4,elinewidth = 2, capsize = 4, color='#7cd902',label = 'no-MDA')
#plt.errorbar(df_int_6_DC_NO.recept_,df_int_6_DC_NO.Mean_Intensity_norm_max_mean, yerr=df_int_6_DC_NO.Mean_Intensity_norm_max_std/np.sqrt(len(df_int_6bp_6n_DC_NO.date)/7), fmt='o-', markersize = 7, capthick=4,elinewidth = 2, capsize = 4, color='#0210d9',label = 'no MDA')


plt.xscale('log')
plt.yscale('log')

plt.title("Bound fraction vs Receptor Density Design A ")
plt.ylim(1E-2,2)
#plt.xlim(-1,1E6)
plt.xlabel('Receptor density / $\\mu m^{-2}$')
plt.ylabel('Bound fraction $\\Theta$')
plt.grid()
plt.legend()
#name = '6bp_6n_mean_adsorption.png'
#plt.savefig((os.path.join(path, name)), format='png') #this in case I want to export the image as png
plt.show()
# Out:
# C:\Users\vquir\anaconda3\lib\site-packages\numpy\core\_methods.py:44: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims, initial, where)
# C:\Users\vquir\anaconda3\lib\site-packages\numpy\core\_methods.py:40: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial, where)

# %% [markdown]
# # OLD DATA - Design A results

# %% [markdown]
# ## Separate experiments are inserted for comparison

# %%
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import os
import glob
import pandas as pd
import numpy as np
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 22}

plt.rc('font', **font)

from pylab import rcParams
rcParams['figure.figsize'] = 12, 8

float_epsilon = np.finfo(np.float64).eps
LSQ_PARAMS = dict(method='trf', max_nfev=5000, xtol=float_epsilon, ftol=float_epsilon,
                  gtol=float_epsilon, jac='3-point', x_scale='jac', loss='soft_l1', verbose=1, f_scale = 0.5,
                  tr_options=dict(tr_solver='lsmr', regularize=True))
                  
###Read 6bp##########################
#name = 'Intensity_python.csv'
#path = 'W:\\staff-bulk\\tnw\\BN\\LL\\Shared\\ChristineL\\PhD\\DataAnalysis_aktuell\\Nanostars\\Superselectivity\\'
#df_int_ns = pd.read_csv(os.path.join(path, name))
#df = []

name = 'Intensity_python2.csv'
path = 'W:\\staff-bulk\\tnw\\BN\\LL\\Shared\\Valentina\\Data_Analysis\\ChristineData\\'
df_int_ns = pd.read_csv((os.path.join(path, name)))
df = []

# %%
df_int_ns
# Out:
#          date  Inert  Number_arms  Sticky_ends  nanostar_concentration[M]  \
# 0    20210219      0            3            3               1.000000e-07
# 1    20210219      0            3            3               1.000000e-07
# 2    20210219      0            3            3               1.000000e-07
# 3    20210219      0            3            3               1.000000e-07
# 4    20210219      0            3            3               1.000000e-07
# ..        ...    ...          ...          ...                        ...
# 217  20220331      0            6            6               1.000000e-08
# 218  20220331      0            6            6               1.000000e-08
# 219  20220331      0            6            6               1.000000e-08
# 220  20220331      0            6            6               1.000000e-08
# 221  20220331      0            6            6               1.000000e-08
#
#      recept    Stickyend  GibbsFreeEnergy  Mean_Intensity  \
# 0         0  GTAGAAGTAGG              -17    5.840575e+07
# 1       200  GTAGAAGTAGG              -17    6.334772e+07
# 2      2000  GTAGAAGTAGG              -17    7.912437e+07
# 3     20000  GTAGAAGTAGG              -17    3.538491e+08
# 4    100000  GTAGAAGTAGG              -17    1.287701e+09
# ..      ...          ...              ...             ...
# 217   10000          ACT               -1    2.463422e+02
# 218   20000          ACT               -1    3.046614e+02
# 219   50000          ACT               -1    4.334876e+02
# 220  150000          ACT               -1    5.667654e+02
# 221  300000          ACT               -1    9.472445e+02
#
#      Mean_Intensity_norm_min         I_max          I_br  \
# 0                   1.000000  1.805149e+09  5.840575e+07
# 1                   1.084614  1.805149e+09  5.840575e+07
# 2                   1.354736  1.805149e+09  5.840575e+07
# 3                   6.058463  1.805149e+09  5.840575e+07
# 4                  22.047501  1.805149e+09  5.840575e+07
# ..                       ...           ...           ...
# 217                 1.095982  9.472445e+02  2.247684e+02
# 218                 1.355446  9.472445e+02  2.247684e+02
# 219                 1.928597  9.472445e+02  2.247684e+02
# 220                 2.521553  9.472445e+02  2.247684e+02
# 221                 4.214313  9.472445e+02  2.247684e+02
#
#      Mean_Intensity_norm_max
# 0                   0.000000
# 1                   0.002829
# 2                   0.011861
# 3                   0.169140
# 4                   0.703764
# ..                       ...
# 217                 0.029861
# 218                 0.110582
# 219                 0.288894
# 220                 0.473368
# 221                 1.000000
#
# [222 rows x 13 columns]

# %% [markdown]
# ## Experiment 20210921

# %%
df_int_6_1 = df_int_ns[df_int_ns['Stickyend'] == 'ACTTCT']
df_int_6_1 = df_int_6_1[df_int_6_1['nanostar_concentration[M]'] == 1.00E-08]
df_int_6bp_6n_1 = df_int_6_1[df_int_6_1['Number_arms'] == 6]
df_int_6_1 = df_int_6_1[df_int_6_1['Sticky_ends'] == 6]
df_int_6_1 = df_int_6_1[df_int_6_1['date'] == 20210921]

# %%
df_int_6_1
# Out:
#         date  Inert  Number_arms  Sticky_ends  nanostar_concentration[M]  \
# 49  20210921      0            6            6               1.000000e-08
# 50  20210921      0            6            6               1.000000e-08
# 51  20210921      0            6            6               1.000000e-08
# 52  20210921      0            6            6               1.000000e-08
# 53  20210921      0            6            6               1.000000e-08
# 54  20210921      0            6            6               1.000000e-08
# 55  20210921      0            6            6               1.000000e-08
#
#     recept Stickyend  GibbsFreeEnergy  Mean_Intensity  \
# 49       0    ACTTCT               -7        247.7394
# 50    2000    ACTTCT               -7        352.0590
# 51   20000    ACTTCT               -7       1445.3472
# 52   40000    ACTTCT               -7       2146.6552
# 53  100000    ACTTCT               -7       2263.9570
# 54  300000    ACTTCT               -7       2162.6396
# 55  600000    ACTTCT               -7       2052.5658
#
#     Mean_Intensity_norm_min     I_max      I_br  Mean_Intensity_norm_max
# 49                 1.000000  2263.957  247.7394                 0.000000
# 50                 1.421086  2263.957  247.7394                 0.051740
# 51                 5.834143  2263.957  247.7394                 0.593987
# 52                 8.664973  2263.957  247.7394                 0.941821
# 53                 9.138462  2263.957  247.7394                 1.000000
# 54                 8.729494  2263.957  247.7394                 0.949749
# 55                 8.285181  2263.957  247.7394                 0.895155

# %% [markdown]
# ## Experiment 20210922

# %%
df_int_6_2 = df_int_ns[df_int_ns['Stickyend'] == 'ACTTCT']
df_int_6_2 = df_int_6_2[df_int_6_2['nanostar_concentration[M]'] == 1.00E-08]
df_int_6_2 = df_int_6_2[df_int_6_2['date'] == 20210922]
df_int_6bp_6n_2 = df_int_6_2[df_int_6_2['Number_arms'] == 6]
df_int_6bp_6n_2 = df_int_6bp_6n_2[df_int_6bp_6n_2['Sticky_ends'] == 6]

# %%
df_int_6_2
# Out:
#         date  Inert  Number_arms  Sticky_ends  nanostar_concentration[M]  \
# 56  20210922      0            6            6               1.000000e-08
# 57  20210922      0            6            6               1.000000e-08
# 58  20210922      0            6            6               1.000000e-08
# 59  20210922      0            6            6               1.000000e-08
# 60  20210922      0            6            6               1.000000e-08
# 61  20210922      0            6            6               1.000000e-08
# 62  20210922      0            6            6               1.000000e-08
#
#     recept Stickyend  GibbsFreeEnergy  Mean_Intensity  \
# 56       0    ACTTCT               -7        244.8652
# 57    2000    ACTTCT               -7        375.4800
# 58    6000    ACTTCT               -7        632.0024
# 59   20000    ACTTCT               -7       1430.0760
# 60   40000    ACTTCT               -7       1961.9300
# 61  100000    ACTTCT               -7       1960.8864
# 62  300000    ACTTCT               -7       2113.4204
#
#     Mean_Intensity_norm_min      I_max      I_br  Mean_Intensity_norm_max
# 56                 1.000000  2113.4204  244.8652                 0.000000
# 57                 1.533415  2113.4204  244.8652                 0.069901
# 58                 2.581022  2113.4204  244.8652                 0.207185
# 59                 5.840258  2113.4204  244.8652                 0.634293
# 60                 8.012286  2113.4204  244.8652                 0.918926
# 61                 8.008024  2113.4204  244.8652                 0.918368
# 62                 8.630955  2113.4204  244.8652                 1.000000

# %%
df_int_6bp_6n_2
# Out:
#         date  Inert  Number_arms  Sticky_ends  nanostar_concentration[M]  \
# 56  20210922      0            6            6               1.000000e-08
# 57  20210922      0            6            6               1.000000e-08
# 58  20210922      0            6            6               1.000000e-08
# 59  20210922      0            6            6               1.000000e-08
# 60  20210922      0            6            6               1.000000e-08
# 61  20210922      0            6            6               1.000000e-08
# 62  20210922      0            6            6               1.000000e-08
#
#     recept Stickyend  GibbsFreeEnergy  Mean_Intensity  \
# 56       0    ACTTCT               -7        244.8652
# 57    2000    ACTTCT               -7        375.4800
# 58    6000    ACTTCT               -7        632.0024
# 59   20000    ACTTCT               -7       1430.0760
# 60   40000    ACTTCT               -7       1961.9300
# 61  100000    ACTTCT               -7       1960.8864
# 62  300000    ACTTCT               -7       2113.4204
#
#     Mean_Intensity_norm_min      I_max      I_br  Mean_Intensity_norm_max
# 56                 1.000000  2113.4204  244.8652                 0.000000
# 57                 1.533415  2113.4204  244.8652                 0.069901
# 58                 2.581022  2113.4204  244.8652                 0.207185
# 59                 5.840258  2113.4204  244.8652                 0.634293
# 60                 8.012286  2113.4204  244.8652                 0.918926
# 61                 8.008024  2113.4204  244.8652                 0.918368
# 62                 8.630955  2113.4204  244.8652                 1.000000

# %% [markdown]
# ## Experiment 20210930

# %%
df_int_6_3 = df_int_ns[df_int_ns['Stickyend'] == 'ACTTCT']
df_int_6_3 = df_int_6_3[df_int_6_3['nanostar_concentration[M]'] == 1.00E-08]
df_int_6_3 = df_int_6_3[df_int_6_3['date'] == 20210930]
df_int_6_3 = df_int_6_3[df_int_6_3['Inert'] == 0]
df_int_6bp_6n_3 = df_int_6_3[df_int_6_3['Number_arms'] == 6]
df_int_6bp_6n_3 = df_int_6bp_6n_3[df_int_6bp_6n_3['Sticky_ends'] == 6]
df_int_6bp_6n_3 = df_int_6bp_6n_3[df_int_6bp_6n_3['Inert'] == 0]

# %%
df_int_6_3
# Out:
#         date  Inert  Number_arms  Sticky_ends  nanostar_concentration[M]  \
# 77  20210930      0            6            6               1.000000e-08
# 78  20210930      0            6            6               1.000000e-08
# 79  20210930      0            6            6               1.000000e-08
# 80  20210930      0            6            6               1.000000e-08
# 81  20210930      0            6            6               1.000000e-08
# 82  20210930      0            6            6               1.000000e-08
# 83  20210930      0            6            6               1.000000e-08
#
#     recept Stickyend  GibbsFreeEnergy  Mean_Intensity  \
# 77       0    ACTTCT               -7        589.1994
# 78    1000    ACTTCT               -7        727.5896
# 79    3000    ACTTCT               -7       1144.3168
# 80   10000    ACTTCT               -7       2999.4714
# 81   20000    ACTTCT               -7       5705.1106
# 82   50000    ACTTCT               -7      10041.2562
# 83  150000    ACTTCT               -7       7695.2204
#
#     Mean_Intensity_norm_min       I_max      I_br  Mean_Intensity_norm_max
# 77                 1.000000  10041.2562  589.1994                 0.000000
# 78                 1.234878  10041.2562  589.1994                 0.014641
# 79                 1.942155  10041.2562  589.1994                 0.058730
# 80                 5.090758  10041.2562  589.1994                 0.255000
# 81                 9.682818  10041.2562  589.1994                 0.541248
# 82                17.042204  10041.2562  589.1994                 1.000000
# 83                13.060469  10041.2562  589.1994                 0.751796

# %% [markdown]
# ## Experiment 20210923

# %%
df_int_6_4 = df_int_ns[df_int_ns['Stickyend'] == 'ACTTCT']
df_int_6_4 = df_int_6_4[df_int_6_4['nanostar_concentration[M]'] == 1.00E-08]
df_int_6_4 = df_int_6_4[df_int_6_4['date'] == 20210923]
df_int_6_4 = df_int_6_4[df_int_6_4['Sticky_ends'] == 6]
df_int_6bp_6n_4 = df_int_6_4[df_int_6_4['Number_arms'] == 6]
#df_int_6bp_6n_4 = df_int_6bp_6n_4[df_int_6bp_6n_4['Sticky_ends'] == 6]

# %%
df_int_6_4
# Out:
#          date  Inert  Number_arms  Sticky_ends  nanostar_concentration[M]  \
# 133  20210923      0            6            6               1.000000e-08
# 134  20210923      0            6            6               1.000000e-08
# 135  20210923      0            6            6               1.000000e-08
# 136  20210923      0            6            6               1.000000e-08
# 137  20210923      0            6            6               1.000000e-08
# 138  20210923      0            6            6               1.000000e-08
# 139  20210923      0            6            6               1.000000e-08
#
#      recept Stickyend  GibbsFreeEnergy  Mean_Intensity  \
# 133       0    ACTTCT               -7        341.3962
# 134    2000    ACTTCT               -7        990.0844
# 135    6000    ACTTCT               -7        577.1026
# 136   20000    ACTTCT               -7       1416.7962
# 137   40000    ACTTCT               -7       2422.5268
# 138  100000    ACTTCT               -7       2272.7904
# 139  300000    ACTTCT               -7       1982.5712
#
#      Mean_Intensity_norm_min      I_max      I_br  Mean_Intensity_norm_max
# 133                 1.000000  2422.5268  341.3962                 0.000000
# 134                 2.900104  2422.5268  341.3962                 0.311700
# 135                 1.690419  2422.5268  341.3962                 0.113259
# 136                 4.150006  2422.5268  341.3962                 0.516738
# 137                 7.095940  2422.5268  341.3962                 1.000000
# 138                 6.657339  2422.5268  341.3962                 0.928050
# 139                 5.807244  2422.5268  341.3962                 0.788598

# %% [markdown]
# # Adding Experiment 1 Design A to compare

# %%
name = 'Separate_Experiments_Edits_Intensity_python.csv' #Insert here other data set to compare
path = 'W:\\staff-bulk\\tnw\\BN\LL\\Shared\\Valentina\\Data_Analysis\\SeparateExperimentsBoundFraction\\'

df_int_ns = pd.read_csv((os.path.join(path, name)))
df = []

df_int_6_DA_1 = df_int_ns[df_int_ns['Stickyend'] == 'GTAGAA']
df_int_6_DA_1 = df_int_6_DA_1[df_int_6_DA_1['nanostar_concentration[M]'] == 1.00E-08]
df_int_6_DA_1 = df_int_6_DA_1[df_int_6_DA_1['date'] == 20231101]
df_int_6bp_6n_DA_1 = df_int_6_DA_1[df_int_6_DA_1['Number_arms'] == 6]
df_int_6bp_6n_DA_1 = df_int_6bp_6n_DA_1[df_int_6bp_6n_DA_1['Sticky_ends'] == 6]

# %%
df_int_6bp_6n_DA_1
# Out:
#           date  Inert  Number_arms  Sticky_ends  nanostar_concentration[M]  \
# 29  20231101.0    0.0          6.0          6.0               1.000000e-08
# 30  20231101.0    0.0          6.0          6.0               1.000000e-08
# 31  20231101.0    0.0          6.0          6.0               1.000000e-08
# 32  20231101.0    0.0          6.0          6.0               1.000000e-08
# 33  20231101.0    0.0          6.0          6.0               1.000000e-08
# 34  20231101.0    0.0          6.0          6.0               1.000000e-08
# 35  20231101.0    0.0          6.0          6.0               1.000000e-08
#
#       recept Stickyend  GibbsFreeEnergy  Mean_Intensity  I_max   I_br  \
# 29       0.0    GTAGAA             -7.0           685.0  862.0  685.0
# 30    1000.0    GTAGAA             -7.0           736.0  862.0  685.0
# 31   10000.0    GTAGAA             -7.0           742.0  862.0  685.0
# 32   20000.0    GTAGAA             -7.0           766.0  862.0  685.0
# 33   50000.0    GTAGAA             -7.0           798.0  862.0  685.0
# 34  150000.0    GTAGAA             -7.0           862.0  862.0  685.0
# 35  300000.0    GTAGAA             -7.0           832.0  862.0  685.0
#
#     Mean_Intensity_norm_max
# 29                    0.000
# 30                    0.288
# 31                    0.322
# 32                    0.458
# 33                    0.638
# 34                    1.000
# 35                    0.831

# %%
df_int_6_DA_1
# Out:
#           date  Inert  Number_arms  Sticky_ends  nanostar_concentration[M]  \
# 29  20231101.0    0.0          6.0          6.0               1.000000e-08
# 30  20231101.0    0.0          6.0          6.0               1.000000e-08
# 31  20231101.0    0.0          6.0          6.0               1.000000e-08
# 32  20231101.0    0.0          6.0          6.0               1.000000e-08
# 33  20231101.0    0.0          6.0          6.0               1.000000e-08
# 34  20231101.0    0.0          6.0          6.0               1.000000e-08
# 35  20231101.0    0.0          6.0          6.0               1.000000e-08
#
#       recept Stickyend  GibbsFreeEnergy  Mean_Intensity  I_max   I_br  \
# 29       0.0    GTAGAA             -7.0           685.0  862.0  685.0
# 30    1000.0    GTAGAA             -7.0           736.0  862.0  685.0
# 31   10000.0    GTAGAA             -7.0           742.0  862.0  685.0
# 32   20000.0    GTAGAA             -7.0           766.0  862.0  685.0
# 33   50000.0    GTAGAA             -7.0           798.0  862.0  685.0
# 34  150000.0    GTAGAA             -7.0           862.0  862.0  685.0
# 35  300000.0    GTAGAA             -7.0           832.0  862.0  685.0
#
#     Mean_Intensity_norm_max
# 29                    0.000
# 30                    0.288
# 31                    0.322
# 32                    0.458
# 33                    0.638
# 34                    1.000
# 35                    0.831

# %% [markdown]
# # Experiment 20231110

# %%
df_int_6_DA_2 = df_int_ns[df_int_ns['Stickyend'] == 'GTAGAA']
df_int_6_DA_2 = df_int_6_DA_2[df_int_6_DA_2['nanostar_concentration[M]'] == 1.00E-08]
df_int_6_DA_2 = df_int_6_DA_2[df_int_6_DA_2['date'] == 20231110]
df_int_6bp_6n_DA_2 = df_int_6_DA_2[df_int_6_DA_2['Number_arms'] == 6]
df_int_6bp_6n_DA_2 = df_int_6bp_6n_DA_2[df_int_6bp_6n_DA_2['Sticky_ends'] == 6]

# %%
df_int_6_DA_2
# Out:
#           date  Inert  Number_arms  Sticky_ends  nanostar_concentration[M]  \
# 36  20231110.0    0.0          6.0          6.0               1.000000e-08
# 37  20231110.0    0.0          6.0          6.0               1.000000e-08
# 38  20231110.0    0.0          6.0          6.0               1.000000e-08
# 39  20231110.0    0.0          6.0          6.0               1.000000e-08
# 40  20231110.0    0.0          6.0          6.0               1.000000e-08
# 41  20231110.0    0.0          6.0          6.0               1.000000e-08
# 42  20231110.0    0.0          6.0          6.0               1.000000e-08
#
#       recept Stickyend  GibbsFreeEnergy  Mean_Intensity   I_max    I_br  \
# 36       0.0    GTAGAA             -7.0          1720.0  4310.0  1720.0
# 37    1000.0    GTAGAA             -7.0          1830.0  4310.0  1720.0
# 38   10000.0    GTAGAA             -7.0          2070.0  4310.0  1720.0
# 39   20000.0    GTAGAA             -7.0          2340.0  4310.0  1720.0
# 40   50000.0    GTAGAA             -7.0          4310.0  4310.0  1720.0
# 41  150000.0    GTAGAA             -7.0          2780.0  4310.0  1720.0
# 42  300000.0    GTAGAA             -7.0          2290.0  4310.0  1720.0
#
#     Mean_Intensity_norm_max
# 36                   0.0000
# 37                   0.0427
# 38                   0.1370
# 39                   0.2400
# 40                   1.0000
# 41                   0.4100
# 42                   0.2210

# %% [markdown]
# # Experiment 20231111 = no MDA

# %%
df_int_6_DA_3 = df_int_ns[df_int_ns['Stickyend'] == 'GTAGAA']
df_int_6_DA_3 = df_int_6_DA_3[df_int_6_DA_3['nanostar_concentration[M]'] == 1.00E-08]
df_int_6_DA_3 = df_int_6_DA_3[df_int_6_DA_3['date'] == 20231111]
df_int_6bp_6n_DA_3 = df_int_6_DA_3[df_int_6_DA_3['Number_arms'] == 6]
df_int_6bp_6n_DA_3 = df_int_6bp_6n_DA_3[df_int_6bp_6n_DA_3['Sticky_ends'] == 6]

# %%
df_int_6_DA_3
# Out:
#           date  Inert  Number_arms  Sticky_ends  nanostar_concentration[M]  \
# 43  20231111.0    0.0          6.0          6.0               1.000000e-08
# 44  20231111.0    0.0          6.0          6.0               1.000000e-08
# 45  20231111.0    0.0          6.0          6.0               1.000000e-08
# 46  20231111.0    0.0          6.0          6.0               1.000000e-08
# 47  20231111.0    0.0          6.0          6.0               1.000000e-08
# 48  20231111.0    0.0          6.0          6.0               1.000000e-08
# 49  20231111.0    0.0          6.0          6.0               1.000000e-08
#
#       recept Stickyend  GibbsFreeEnergy  Mean_Intensity   I_max    I_br  \
# 43       0.0    GTAGAA             -7.0          2070.0  2940.0  2070.0
# 44    1000.0    GTAGAA             -7.0          2580.0  2940.0  2070.0
# 45   10000.0    GTAGAA             -7.0          2210.0  2940.0  2070.0
# 46   20000.0    GTAGAA             -7.0          2820.0  2940.0  2070.0
# 47   50000.0    GTAGAA             -7.0          2940.0  2940.0  2070.0
# 48  150000.0    GTAGAA             -7.0          2910.0  2940.0  2070.0
# 49  300000.0    GTAGAA             -7.0          2350.0  2940.0  2070.0
#
#     Mean_Intensity_norm_max
# 43                    0.000
# 44                    0.583
# 45                    0.163
# 46                    0.859
# 47                    1.000
# 48                    0.962
# 49                    0.322

# %% [markdown]
# # Plot old data 6 arm/6bps per experiment

# %%
fig = plt.figure(figsize=(12, 12))

#Adding Design A results 

plt.errorbar(df_int_6_DA_3.recept,df_int_6_DA_3.Mean_Intensity_norm_max, fmt='o-', markersize = 7, capthick=4,elinewidth = 2, capsize = 4, color='#d902be',label = '20231110 - no MDA')
plt.errorbar(df_int_6_DA_2.recept,df_int_6_DA_2.Mean_Intensity_norm_max, fmt='o-', markersize = 7, capthick=4,elinewidth = 2, capsize = 4, color='#d58181',label = '20231110')
plt.errorbar(df_int_6_DA_1.recept,df_int_6_DA_1.Mean_Intensity_norm_max, fmt='o-', markersize = 7, capthick=4,elinewidth = 2, capsize = 4, color='#8902d9',label = '20231101')


#Old Data
plt.errorbar(df_int_6_4.recept,df_int_6_4.Mean_Intensity_norm_max, fmt='o-', markersize = 7, capthick=4,elinewidth = 2, capsize = 4, color='#d95f02',label = '20210923')
plt.errorbar(df_int_6_3.recept,df_int_6_3.Mean_Intensity_norm_max, fmt='o-', markersize = 7, capthick=4,elinewidth = 2, capsize = 4, color='#313ec6',label = '20210930')
plt.errorbar(df_int_6bp_6n_2.recept,df_int_6bp_6n_2.Mean_Intensity_norm_max, fmt='o-', markersize = 7, capthick=4,elinewidth = 2, capsize = 4, color='#02d999',label = '20210922')
plt.errorbar(df_int_6_1.recept,df_int_6_1.Mean_Intensity_norm_max, fmt='o-', markersize = 7, capthick=4,elinewidth = 2, capsize = 4, color='#119c4d',label = '20210921')


plt.xscale('log')
plt.yscale('log')
#plt.ylim(0.001,15)
#plt.xlim(10,10000000)
plt.xlabel('Receptor density / $\\mu m^{-2}$')
plt.ylabel('Bound fraction $\\Theta$')
plt.title("Comparison Bound fraction vs Receptor Density for 6 arm - 6 bps NS")
plt.grid()
plt.legend()
#name = '6bp_6n_mean_adsorption.png'
#plt.savefig((os.path.join(path, name)), format='png')
plt.show()

# %%
fig = plt.figure(figsize=(12, 12))

#Adding Design A results 

plt.errorbar(df_int_6_DA_3.recept,df_int_6_DA_3.Mean_Intensity_norm_max, fmt='o-', markersize = 7, capthick=4,elinewidth = 2, capsize = 4, color='#d902be',label = '20231110 - no MDA')
plt.errorbar(df_int_6_DA_2.recept,df_int_6_DA_2.Mean_Intensity_norm_max, fmt='o-', markersize = 7, capthick=4,elinewidth = 2, capsize = 4, color='#d58181',label = '20231110')
plt.errorbar(df_int_6_DA_1.recept,df_int_6_DA_1.Mean_Intensity_norm_max, fmt='o-', markersize = 7, capthick=4,elinewidth = 2, capsize = 4, color='#8902d9',label = '20231101')


plt.xscale('log')
plt.yscale('log')
#plt.ylim(0.001,15)
#plt.xlim(10,10000000)
plt.xlabel('Receptor density / $\\mu m^{-2}$')
plt.ylabel('Bound fraction $\\Theta$')
plt.title("Comparison Bound fraction vs Receptor Density for Design A")
plt.grid()
plt.legend()
#name = '6bp_6n_mean_adsorption.png'
#plt.savefig((os.path.join(path, name)), format='png')
plt.show()

# %% [markdown]
# # Average dataframes

# %%
name = 'Intensity_python2.csv' #new excel file with Christine's data
path = 'W:\\staff-bulk\\tnw\\BN\\LL\\Shared\\Valentina\\Data_Analysis\\ChristineData\\'
df_int_ns = pd.read_csv((os.path.join(path, name)))
df = []


df_int_6 = df_int_ns[df_int_ns['Stickyend'] == 'ACTTCT']
df_int_6 = df_int_6[df_int_6['nanostar_concentration[M]'] == 1.00E-08]
#df_int_6_inert = df_int_6[df_int_6['Inert'] == 1] # a lead into excel file with 6 arm/6bps with 1 inert arm but 6 sticky end value and different number of bps in sticky end receptor
df_int_6 = df_int_6[df_int_6['Inert'] == 0]

df_int_6bp_6n = df_int_6[df_int_6['Number_arms'] == 6]
df_int_6bp_6n = df_int_6bp_6n[df_int_6bp_6n['Sticky_ends'] == 6]



df_int_ns = pd.read_csv((os.path.join(path, name)))
df_int_4 = df_int_ns[df_int_ns['Stickyend'] == 'ACTT']
df_int_4 = df_int_4[df_int_4['nanostar_concentration[M]'] == 1.00E-08]
#df_int_4_inert = df_int_4[df_int_4['Inert'] == 1]
df_int_4 = df_int_4[df_int_4['Inert'] == 0]
df_int_4bp_6n = df_int_4[df_int_4['Sticky_ends'] == 6]
#df_int_4bp_6n_inert = df_int_4_inert[df_int_4_inert['Sticky_ends'] == 6]

# %%
#####6bp###########
df_6_6n = df_int_6bp_6n.groupby(['recept'], as_index = True).agg({'Mean_Intensity_norm_max': ['mean', 'std']}).reset_index()
df_6_6n.columns = ['_'.join(col).strip() for col in df_6_6n.columns.values]

######4bp############
df_4_6n = df_int_4bp_6n.groupby(['recept'], as_index = True).agg({'Mean_Intensity_norm_max': ['mean', 'std']}).reset_index()
df_4_6n.columns = ['_'.join(col).strip() for col in df_4_6n.columns.values]

# %%
df_int_ns
# Out:
#          date  Inert  Number_arms  Sticky_ends  nanostar_concentration[M]  \
# 0    20210219      0            3            3               1.000000e-07
# 1    20210219      0            3            3               1.000000e-07
# 2    20210219      0            3            3               1.000000e-07
# 3    20210219      0            3            3               1.000000e-07
# 4    20210219      0            3            3               1.000000e-07
# ..        ...    ...          ...          ...                        ...
# 217  20220331      0            6            6               1.000000e-08
# 218  20220331      0            6            6               1.000000e-08
# 219  20220331      0            6            6               1.000000e-08
# 220  20220331      0            6            6               1.000000e-08
# 221  20220331      0            6            6               1.000000e-08
#
#      recept    Stickyend  GibbsFreeEnergy  Mean_Intensity  \
# 0         0  GTAGAAGTAGG              -17    5.840575e+07
# 1       200  GTAGAAGTAGG              -17    6.334772e+07
# 2      2000  GTAGAAGTAGG              -17    7.912437e+07
# 3     20000  GTAGAAGTAGG              -17    3.538491e+08
# 4    100000  GTAGAAGTAGG              -17    1.287701e+09
# ..      ...          ...              ...             ...
# 217   10000          ACT               -1    2.463422e+02
# 218   20000          ACT               -1    3.046614e+02
# 219   50000          ACT               -1    4.334876e+02
# 220  150000          ACT               -1    5.667654e+02
# 221  300000          ACT               -1    9.472445e+02
#
#      Mean_Intensity_norm_min         I_max          I_br  \
# 0                   1.000000  1.805149e+09  5.840575e+07
# 1                   1.084614  1.805149e+09  5.840575e+07
# 2                   1.354736  1.805149e+09  5.840575e+07
# 3                   6.058463  1.805149e+09  5.840575e+07
# 4                  22.047501  1.805149e+09  5.840575e+07
# ..                       ...           ...           ...
# 217                 1.095982  9.472445e+02  2.247684e+02
# 218                 1.355446  9.472445e+02  2.247684e+02
# 219                 1.928597  9.472445e+02  2.247684e+02
# 220                 2.521553  9.472445e+02  2.247684e+02
# 221                 4.214313  9.472445e+02  2.247684e+02
#
#      Mean_Intensity_norm_max
# 0                   0.000000
# 1                   0.002829
# 2                   0.011861
# 3                   0.169140
# 4                   0.703764
# ..                       ...
# 217                 0.029861
# 218                 0.110582
# 219                 0.288894
# 220                 0.473368
# 221                 1.000000
#
# [222 rows x 13 columns]

# %% [markdown]
# # Plot bound fraction vs receptor density all Designs to Compare

# %%
                  
###Read 6bp##########################
name = 'Separate_Experiments_Edits_Intensity_python.csv' #Insert here other data set to compare
path = 'W:\\staff-bulk\\tnw\\BN\LL\\Shared\\Valentina\\Data_Analysis\\AlphaFitChanges\\'
df_int_nsC = pd.read_csv((os.path.join(path, name)))
df = []

#this are 6arm/4bps NS 2022 - Design A*
df_int_6nC = df_int_nsC[df_int_nsC['Stickyend'] == 'GTAG']
df_int_6nC = df_int_6nC[df_int_6nC['nanostar_concentration[M]'] == 1.00E-08]
df_int_6bp_6nC = df_int_6nC[df_int_6nC['Number_arms'] == 6]
df_int_6bp_6nC = df_int_6bp_6nC[df_int_6bp_6nC['Sticky_ends'] == 4]

#this are Design A experiments 2023
df_int_6_DA = df_int_nsC[df_int_nsC['Stickyend'] == 'GTAGAA']
df_int_6_DA = df_int_6_DA[df_int_6_DA['nanostar_concentration[M]'] == 1.00E-08]
df_int_6bp_6n_DA = df_int_6_DA[df_int_6_DA['Number_arms'] == 6]
df_int_6bp_6n_DA = df_int_6bp_6n_DA[df_int_6bp_6n_DA['Sticky_ends'] == 6]

# %%
#Design A
df_int_6_DA = df_int_6bp_6n_DA.groupby(['recept'], as_index = True).agg({'Mean_Intensity_norm_max': ['mean', 'std']}).reset_index()
df_int_6_DA.columns = ['_'.join(col).strip() for col in df_int_6_DA.columns.values]

# %% [markdown]
# # Add here for comparison graph, new data

# %%
fig = plt.figure(figsize=(12, 12))

plt.errorbar(df_int_6_DC.recept_,df_int_6_DC.Mean_Intensity_norm_max_mean, yerr=df_int_6_DC.Mean_Intensity_norm_max_std/np.sqrt(len(df_int_6bp_6n_DC.date)/7), fmt='o-', markersize = 7, capthick=4,elinewidth = 2, capsize = 4, color='#d9027c',label = 'Design C')
#plt.errorbar(df_6_6n.recept_,df_6_6n.Mean_Intensity_norm_max_mean, yerr=df_6_6n.Mean_Intensity_norm_max_std/np.sqrt(len(df_int_6bp_6n.date)/7), fmt='o-', markersize = 7, capthick=4,elinewidth = 2, capsize = 4, color='#d95f02',label = 'Design A old')
#plt.errorbar(df_4_6n.recept_,df_4_6n.Mean_Intensity_norm_max_mean, yerr=df_4_6n.Mean_Intensity_norm_max_std/np.sqrt(len(df_int_4bp_6n.date)/7), fmt='o-', markersize = 7, capthick=4,elinewidth = 2, capsize = 4, color='#66a61e',label = '6arm/4bps old')
#plt.errorbar(df_int_6_DA.recept_,df_int_6_DA.Mean_Intensity_norm_max_mean, yerr=df_int_6_DA.Mean_Intensity_norm_max_std/np.sqrt(len(df_int_6bp_6n_DA.date)/7), fmt='o-', markersize = 7, capthick=4,elinewidth = 2, capsize = 4, color='#02d9cb',label = 'Design A new')
#plt.errorbar(df_6_6nC.recept_,df_6_6nC.Mean_Intensity_norm_max_mean, yerr=df_6_6nC.Mean_Intensity_norm_max_std/np.sqrt(len(df_int_6bp_6nC.date)/7), fmt='o-', markersize = 7, capthick=4,elinewidth = 2, capsize = 4, color='#5f02d9',label = 'Design A*')

#C variations
#plt.errorbar(df_int_6_DC_2h.recept_,df_int_6_DC_2h.Mean_Intensity_norm_max_mean, yerr=df_int_6_DC_2h.Mean_Intensity_norm_max_std/np.sqrt(len(df_int_6bp_6n_DC_2h.date)/7), fmt='o-', markersize = 7, capthick=4,elinewidth = 2, capsize = 4, color='#7cd902',label = 'MDA+2h')
#plt.errorbar(df_int_6_DC_1h.recept_,df_int_6_DC_1h.Mean_Intensity_norm_max_mean, yerr=df_int_6_DC_1h.Mean_Intensity_norm_max_std/np.sqrt(len(df_int_6bp_6n_DC_1h.date)/7), fmt='o-', markersize = 7, capthick=4,elinewidth = 2, capsize = 4, color='#780109',label = 'MDA+1.5h')

plt.xscale('log')
plt.yscale('log')
plt.ylim(1E-3,1.15)
plt.xlim(100,6500000)
plt.xlabel('Receptor density / $\\mu m^{-2}$')
plt.ylabel('Bound fraction $\\Theta$')
plt.title("Bound Fraction Average")
plt.grid()
plt.legend()
#name = '6bp_10n_6n_3n_1n_mean_adsorption.eps'
#plt.savefig((os.path.join(path + 'eps', name)), format='eps')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 fig = plt.figure(figsize=(12, 12))
#       3 plt.errorbar(df_int_6_DC.recept_,df_int_6_DC.Mean_Intensity_norm_max_mean, yerr=df_int_6_DC.Mean_Intensity_norm_max_std/np.sqrt(len(df_int_6bp_6n_DC.date)/7), fmt='o-', markersize = 7, capthick=4,elinewidth = 2, capsize = 4, color='#d9027c',label = 'Design C')
#       4 #plt.errorbar(df_6_6n.recept_,df_6_6n.Mean_Intensity_norm_max_mean, yerr=df_6_6n.Mean_Intensity_norm_max_std/np.sqrt(len(df_int_6bp_6n.date)/7), fmt='o-', markersize = 7, capthick=4,elinewidth = 2, capsize = 4, color='#d95f02',label = 'Design A old')
#       5 #plt.errorbar(df_4_6n.recept_,df_4_6n.Mean_Intensity_norm_max_mean, yerr=df_4_6n.Mean_Intensity_norm_max_std/np.sqrt(len(df_int_4bp_6n.date)/7), fmt='o-', markersize = 7, capthick=4,elinewidth = 2, capsize = 4, color='#66a61e',label = '6arm/4bps old')
#       6 #plt.errorbar(df_int_6_DA.recept_,df_int_6_DA.Mean_Intensity_norm_max_mean, yerr=df_int_6_DA.Mean_Intensity_norm_max_std/np.sqrt(len(df_int_6bp_6n_DA.date)/7), fmt='o-', markersize = 7, capthick=4,elinewidth = 2, capsize = 4, color='#02d9cb',label = 'Design A new')
#    (...)
#      10 #plt.errorbar(df_int_6_DC_2h.recept_,df_int_6_DC_2h.Mean_Intensity_norm_max_mean, yerr=df_int_6_DC_2h.Mean_Intensity_norm_max_std/np.sqrt(len(df_int_6bp_6n_DC_2h.date)/7), fmt='o-', markersize = 7, capthick=4,elinewidth = 2, capsize = 4, color='#7cd902',label = 'MDA+2h')
#      11 #plt.errorbar(df_int_6_DC_1h.recept_,df_int_6_DC_1h.Mean_Intensity_norm_max_mean, yerr=df_int_6_DC_1h.Mean_Intensity_norm_max_std/np.sqrt(len(df_int_6bp_6n_DC_1h.date)/7), fmt='o-', markersize = 7, capthick=4,elinewidth = 2, capsize = 4, color='#780109',label = 'MDA+1.5h')
#
# NameError: name 'plt' is not defined
